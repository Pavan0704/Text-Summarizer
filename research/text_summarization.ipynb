# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install transformers[sentencepiece] datasets sacrebleu rouge_score py7zr -q
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.8.7 requires cymem<2.1.0,>=2.0.2, which is not installed.
# spacy 3.8.7 requires jinja2, which is not installed.
# spacy 3.8.7 requires pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4, which is not installed.
# spacy 3.8.7 requires spacy-legacy<3.1.0,>=3.0.11, which is not installed.
# spacy 3.8.7 requires spacy-loggers<2.0.0,>=1.0.0, which is not installed.
# spacy 3.8.7 requires typer<1.0.0,>=0.3.0, which is not installed.
# spacy 3.8.7 requires wasabi<1.2.0,>=0.9.1, which is not installed.
# thinc 8.3.6 requires cymem<2.1.0,>=2.0.2, which is not installed.
# thinc 8.3.6 requires pydantic<3.0.0,>=2.0.0, which is not installed.
# thinc 8.3.6 requires wasabi<1.2.0,>=0.8.1, which is not installed.
# weasel 0.4.1 requires pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4, which is not installed.
# weasel 0.4.1 requires smart-open<8.0.0,>=5.2.1, which is not installed.
# weasel 0.4.1 requires typer<1.0.0,>=0.3.0, which is not installed.
# weasel 0.4.1 requires wasabi<1.2.0,>=0.9.1, which is not installed.

# %%
# !pip install --upgrade accelerate 
# !pip uninstall -y transformers accelerate 
# !pip install transformers accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (7.2.1)
# Requirement already satisfied: pyyaml in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (6.0.3)
# Collecting torch>=2.0.0 (from accelerate)
#   Downloading torch-2.9.1-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: requests in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->accelerate)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.0.0->accelerate)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch>=2.0.0->accelerate)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->accelerate)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=2.0.0->accelerate)
#   Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading torch-2.9.1-cp311-cp311-win_amd64.whl (111.0 MB)
#    ---------------------------------------- 0.0/111.0 MB ? eta -:--:--
#    ---------------------------------------- 1.3/111.0 MB 6.7 MB/s eta 0:00:17
#     --------------------------------------- 2.6/111.0 MB 6.3 MB/s eta 0:00:18
#    - -------------------------------------- 3.9/111.0 MB 6.7 MB/s eta 0:00:16
#    -- ------------------------------------- 5.8/111.0 MB 6.9 MB/s eta 0:00:16
#    -- ------------------------------------- 7.1/111.0 MB 6.8 MB/s eta 0:00:16
#    --- ------------------------------------ 8.4/111.0 MB 6.8 MB/s eta 0:00:16
#    --- ------------------------------------ 10.0/111.0 MB 6.8 MB/s eta 0:00:15
#    --- ------------------------------------ 11.0/111.0 MB 6.7 MB/s eta 0:00:15
#    ---- ----------------------------------- 12.3/111.0 MB 6.7 MB/s eta 0:00:15
#    ---- ----------------------------------- 13.4/111.0 MB 6.5 MB/s eta 0:00:16
#    ----- ---------------------------------- 14.2/111.0 MB 6.3 MB/s eta 0:00:16
#    ----- ---------------------------------- 14.9/111.0 MB 6.1 MB/s eta 0:00:16
#    ----- ----------------------------------

#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------------- ----- 6/7 [accelerate]
#    ---------------------------------- ----- 6/7 [accelerate]
#    ---------------------------------- ----- 6/7 [accelerate]
#    ---------------------------------- ----- 6/7 [accelerate]
#    ---------------------------------- ----- 6/7 [accelerate]
#    ---------------------------------------- 7/7 [accelerate]
#
# Successfully installed MarkupSafe-3.0.3 accelerate-1.12.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 sympy-1.14.0 torch-2.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.8.7 requires cymem<2.1.0,>=2.0.2, which is not installed.
# spacy 3.8.7 requires pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4, which is not installed.
# spacy 3.8.7 requires spacy-legacy<3.1.0,>=3.0.11, which is not installed.
# spacy 3.8.7 requires spacy-loggers<2.0.0,>=1.0.0, which is not installed.
# spacy 3.8.7 requires typer<1.0.0,>=0.3.0, which is not installed.
# spacy 3.8.7 requires wasabi<1.2.0,>=0.9.1, which is not installed.
# Found existing installation: transformers 4.57.6
# Uninstalling transformers-4.57.6:
#   Successfully uninstalled transformers-4.57.6
# Found existing installation: accelerate 1.12.0
# Uninstalling accelerate-1.12.0:
#   Successfully uninstalled accelerate-1.12.0
# Collecting transformers
#   Using cached transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Collecting accelerate
#   Using cached accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (3.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (2026.1.15)
# Requirement already satisfied: requests in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: psutil in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (7.2.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from accelerate) (2.9.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pawan\anaconda3\envs\texts\lib\site-packages (from requests->transformers) (2026.1.4)
# Using cached transformers-4.57.6-py3-none-any.whl (12.0 MB)
# Using cached accelerate-1.12.0-py3-none-any.whl (380 kB)
# Installing collected packages: accelerate, transformers
#
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    ---------------------------------------- 0/2 [accelerate]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    -------------------- ------------------- 1/2 [transformers]
#    ---------------------------------------- 2/2 [transformers]
#
# Successfully installed accelerate-1.12.0 transformers-4.57.6

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset, load_from_disk
import matplotlib.pyplot as plt
from datasets import load_dataset
import pandas as pd
from datasets import load_dataset, load_metric

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

import nltk
from nltk.tokenize import sent_tokenize

from tqdm import tqdm
import torch

nltk.download("punkt")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 from transformers import pipeline, set_seed
#       2 from datasets import load_dataset, load_from_disk
# ----> 3 import matplotlib.pyplot as plt
#       4 from datasets import load_dataset
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"

model_ckpt = "google/pegasus-cnn_dailymail"

tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(model_ckpt).to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
# ----> 3 device = "cuda" if torch.cuda.is_available() else "cpu"
#       5 model_ckpt = "google/pegasus-cnn_dailymail"
#       7 tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
#
# NameError: name 'torch' is not defined

# %%
# dowload & unzip data

# !wget https://github.com/entbappy/Branching-tutorial/raw/master/summarizer-data.zip
# !unzip summarizer-data.zip
